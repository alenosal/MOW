# %% [markdown]
# ## Analiza zbioru
# #### Sasnal Jakub & Aleksander Nosal

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

data = pd.read_csv('./insurance.csv', delimiter=',')
# data = data.replace({'smoker': {'yes': 1, 'no': 0}})
# data = data.replace({'sex': {'female': 1, 'male': 0}})
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges  southwest  northwest  \
# 0   19    1  27.900         0       1  16884.92400          1          0
# 1   18    0  33.770         1       0   1725.55230          0          0
# 2   28    0  33.000         3       0   4449.46200          0          0
# 3   33    0  22.705         0       0  21984.47061          0          1
# 4   32    0  28.880         0       0   3866.85520          0          1
#
#    southeast  northeast
# 0          0          0
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             charges    southwest    northwest    southeast    northeast
# count   1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean   13270.422265     0.242900     0.242900     0.272048     0.242152
# std    12110.011237     0.428995     0.428995     0.445181     0.428546
# min     1121.873900     0.000000     0.000000     0.000000     0.000000
# 25%     4740.287150     0.000000     0.000000     0.000000     0.000000
# 50%     9382.033000     0.000000     0.000000     0.000000     0.000000
# 75%    16639.912515     0.000000     0.000000     1.000000     0.000000
# max    63770.428010     1.000000     1.000000     1.000000     1.000000

# %%
le = preprocessing.LabelEncoder()
le.fit(data['charges'])
data['charges']=le.transform(data['charges'])
data.head()
# Out:
#    age  sex     bmi  children  smoker  charges  southwest  northwest  \
# 0   19    1  27.900         0       1     1005          1          0
# 1   18    0  33.770         1       0       57          0          0
# 2   28    0  33.000         3       0      306          0          0
# 3   33    0  22.705         0       0     1097          0          1
# 4   32    0  28.880         0       0      254          0          1
#
#    southeast  northeast
# 0          0          0
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
import seaborn as sns

sns.pairplot(data)

# %%
data_prep = data[data['age'] > 0]
data_prep = data_prep[data_prep['children'] > 0]

sns.pairplot(data_prep[['age', 'charges']])
sns.pairplot(data_prep[['smoker', 'charges']])

# %% [markdown]
# Można zauważyć, że im starsza osoba tym większe opłaty za ubezpieczenie, także duży wpływ ma to czy osoba jest paląca

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt


figure(figsize=(8, 6), dpi=80)

corrMatrix = data_prep.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# Tablica korelacji potwierdza wcześniej postawioną teze. Największa korelacja zależy od tego czy pali a nastęnie od wieku.

# %%
data_prep.describe()
# Out:
#               age         sex         bmi    children      smoker  \
# count  764.000000  764.000000  764.000000  764.000000  764.000000
# mean    39.780105    0.488220   30.748370    1.917539    0.208115
# std     11.927317    0.500189    6.144777    0.983351    0.406226
# min     18.000000    0.000000   16.815000    1.000000    0.000000
# 25%     30.000000    0.000000   26.378750    1.000000    0.000000
# 50%     40.000000    0.000000   30.495000    2.000000    0.000000
# 75%     49.000000    1.000000   34.625000    3.000000    0.000000
# max     64.000000    1.000000   52.580000    5.000000    1.000000
#
#            charges   southwest   northwest   southeast   northeast
# count   764.000000  764.000000  764.000000  764.000000  764.000000
# mean    703.358639    0.244764    0.252618    0.270942    0.231675
# std     351.031966    0.430229    0.434798    0.444738    0.422179
# min      53.000000    0.000000    0.000000    0.000000    0.000000
# 25%     413.500000    0.000000    0.000000    0.000000    0.000000
# 50%     656.500000    0.000000    0.000000    0.000000    0.000000
# 75%    1027.500000    0.000000    1.000000    1.000000    0.000000
# max    1334.000000    1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# Nie ma bardzo odstających danych, które można by uznać za błędne

# %%
np.sum(data_prep.isna())
# Out:
# age          0
# sex          0
# bmi          0
# children     0
# smoker       0
# charges      0
# southwest    0
# northwest    0
# southeast    0
# northeast    0
# dtype: int64

# %%
print(data_prep.columns)

data.hist(figsize=(30, 30))
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'southwest',
#        'northwest', 'southeast', 'northeast'],
#       dtype='object')
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'children'}>,
#         <AxesSubplot:title={'center':'smoker'}>,
#         <AxesSubplot:title={'center':'charges'}>],
#        [<AxesSubplot:title={'center':'southwest'}>,
#         <AxesSubplot:title={'center':'northwest'}>,
#         <AxesSubplot:title={'center':'southeast'}>],
#        [<AxesSubplot:title={'center':'northeast'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Można zauważyć, że w naszych danych opłaty nie mają rozkładu normalnego, więc nie ma dominującej grupy

# %%
data_prep.boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %%
df = data.drop(['charges'], axis = 1)
df.boxplot(figsize=(30, 30))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Jako wortości odstające są u nas osoby o dużym BMI, jenak nie na tyle dużym, żeby usunąć je z danych lub uznać za fałszywe.
